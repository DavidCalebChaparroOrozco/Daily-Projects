# %%
import pandas as pd
from string import ascii_uppercase as alf
import pickle
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## Web Scrapping

# %%
data = pd.read_html("https://es.wikipedia.org/wiki/Copa_Am%C3%A9rica_2024")
data

# data = pd.read_html("https://en.wikipedia.org/wiki/2024_Copa_Am%C3%A9rica")
# data
# Out:
# [    0                                                  1   2
#  0 NaN  Este artículo se refiere o está relacionado co... NaN,
#                                      Copa América 2024  \
#  0                                      XLVIII Edición
#  1   La final se jugará en el Hard Rock Stadium de ...
#  2                                     Datos generales
#  3                                                Sede
#  4                                     Nombre completo
#  5                                               Fecha
#  6                                     Fecha de inicio
#  7                                     Fecha de cierre
#  8                                             Edición
#  9                                         Organizador
#  10                                        Def. título
#  11                                 Datos estadísticos
#  12                                      Participantes
#  13                                           Partidos
# ...

# %%
data
print(data)
# Out:
# [    0                                                  1   2
# 0 NaN  Este artículo se refiere o está relacionado co... NaN,                                     Copa América 2024  \
# 0                                      XLVIII Edición
# 1   La final se jugará en el Hard Rock Stadium de ...
# 2                                     Datos generales
# 3                                                Sede
# 4                                     Nombre completo
# 5                                               Fecha
# 6                                     Fecha de inicio
# 7                                     Fecha de cierre
# 8                                             Edición
# 9                                         Organizador
# 10                                        Def. título
# 11                                 Datos estadísticos
# 12                                      Participantes
# 13                                           Partidos
# ...

# %%
group_A = data[6]
group_A
# Out:
#       Equipo  Pts.  PJ  PG  PE  PP  GF  GC  Dif.
# 0  Argentina     0   0   0   0   0   0   0     0
# 1       Perú     0   0   0   0   0   0   0     0
# 2      Chile     0   0   0   0   0   0   0     0
# 3     Canadá     0   0   0   0   0   0   0     0

# %%
group_B = data[13]
group_B
# Out:
#       Equipo  Pts.  PJ  PG  PE  PP  GF  GC  Dif.
# 0     México     0   0   0   0   0   0   0     0
# 1    Ecuador     0   0   0   0   0   0   0     0
# 2  Venezuela     0   0   0   0   0   0   0     0
# 3    Jamaica     0   0   0   0   0   0   0     0

# %%
group_C = data[20]
group_C
# Out:
#            Equipo  Pts.  PJ  PG  PE  PP  GF  GC  Dif.
# 0  Estados Unidos     0   0   0   0   0   0   0     0
# 1         Uruguay     0   0   0   0   0   0   0     0
# 2          Panamá     0   0   0   0   0   0   0     0
# 3         Bolivia     0   0   0   0   0   0   0     0

# %%
group_D = data[27]
group_D
# Out:
#        Equipo  Pts.  PJ  PG  PE  PP  GF  GC  Dif.
# 0      Brasil     0   0   0   0   0   0   0     0
# 1    Colombia     0   0   0   0   0   0   0     0
# 2    Paraguay     0   0   0   0   0   0   0     0
# 3  Costa Rica     0   0   0   0   0   0   0     0

# %%
# Grupo es desde el A - D
for i in range(6, 28, 7):
    df = data[i]
    print(df)
# Out:
#       Equipo  Pts.  PJ  PG  PE  PP  GF  GC  Dif.
# 0  Argentina     0   0   0   0   0   0   0     0
# 1       Perú     0   0   0   0   0   0   0     0
# 2      Chile     0   0   0   0   0   0   0     0
# 3     Canadá     0   0   0   0   0   0   0     0
#       Equipo  Pts.  PJ  PG  PE  PP  GF  GC  Dif.
# 0     México     0   0   0   0   0   0   0     0
# 1    Ecuador     0   0   0   0   0   0   0     0
# 2  Venezuela     0   0   0   0   0   0   0     0
# 3    Jamaica     0   0   0   0   0   0   0     0
#            Equipo  Pts.  PJ  PG  PE  PP  GF  GC  Dif.
# 0  Estados Unidos     0   0   0   0   0   0   0     0
# 1         Uruguay     0   0   0   0   0   0   0     0
# 2          Panamá     0   0   0   0   0   0   0     0
# 3         Bolivia     0   0   0   0   0   0   0     0
#        Equipo  Pts.  PJ  PG  PE  PP  GF  GC  Dif.
# 0      Brasil     0   0   0   0   0   0   0     0
# 1    Colombia     0   0   0   0   0   0   0     0
# 2    Paraguay     0   0   0   0   0   0   0     0
# ...

# %%
for letter, i in zip(alf, range(6,28, 7)):
    print(letter, i)
# Out:
# A 6
# B 13
# C 20
# D 27

# %%
dict_tables = {}
for letter,i in zip(alf, range(6, 28, 7)):
    df = data[i]
    dict_tables[f'Group {letter}'] = df
dict_tables
# Out:
# {'Group A':       Equipo  Pts.  PJ  PG  PE  PP  GF  GC  Dif.
#  0  Argentina     0   0   0   0   0   0   0     0
#  1       Perú     0   0   0   0   0   0   0     0
#  2      Chile     0   0   0   0   0   0   0     0
#  3     Canadá     0   0   0   0   0   0   0     0,
#  'Group B':       Equipo  Pts.  PJ  PG  PE  PP  GF  GC  Dif.
#  0     México     0   0   0   0   0   0   0     0
#  1    Ecuador     0   0   0   0   0   0   0     0
#  2  Venezuela     0   0   0   0   0   0   0     0
#  3    Jamaica     0   0   0   0   0   0   0     0,
#  'Group C':            Equipo  Pts.  PJ  PG  PE  PP  GF  GC  Dif.
#  0  Estados Unidos     0   0   0   0   0   0   0     0
#  1         Uruguay     0   0   0   0   0   0   0     0
#  2          Panamá     0   0   0   0   0   0   0     0
#  3         Bolivia     0   0   0   0   0   0   0     0,
#  'Group D':        Equipo  Pts.  PJ  PG  PE  PP  GF  GC  Dif.
#  0      Brasil     0   0   0   0   0   0   0     0
# ...

# %%
dict_tables.keys()
# Out:
# dict_keys(['Group A', 'Group B', 'Group C', 'Group D'])

# %%
dict_tables['Group A']
# Out:
#       Equipo  Pts.  PJ  PG  PE  PP  GF  GC  Dif.
# 0  Argentina     0   0   0   0   0   0   0     0
# 1       Perú     0   0   0   0   0   0   0     0
# 2      Chile     0   0   0   0   0   0   0     0
# 3     Canadá     0   0   0   0   0   0   0     0

# %%
with open('dict_table', 'wb') as output:
    pickle.dump(dict_tables, output)

# %% [markdown]
# ## Data Historical

# %%
years = [
    1975, 1979, 1983, 1987, 1989, 1991, 
    1993, 1995, 1997, 1999, 2001, 2004,
    2007, 2011, 2015, 2016, 2019, 2021, 
    2024
         ]

# %%
web = "https://es.wikipedia.org/wiki/Copa_Am%C3%A9rica"
response = requests.get(web)
# print(response.text)
content = response.text
soup = BeautifulSoup(content, 'lxml')

# %%
# center
soup.find_all()
